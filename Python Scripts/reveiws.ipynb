# %%
import pandas as pd
import numpy as np


#  Fill missing text values with English placeholders
dataset['review_comment_title'] = dataset['review_comment_title'].fillna('No Title')
dataset['review_comment_message'] = dataset['review_comment_message'].fillna('No Message')

# Ensure conversion of 'Review Creation Date' Column to DateTime
dataset['review_creation_date'] = pd.to_datetime(dataset['review_creation_date'], errors='coerce')

# Parsing Date for 'Review Creation Date' Column
dataset['review_creation_date'] = dataset['review_creation_date'].dt.date 


# String Standartdization

dataset.columns = dataset.columns.str.replace('_', ' ').str.title()

output = dataset
