# %%
import pandas as pd
import numpy as np 

# String NOrmalization 
   
dataset['payment_type'] = (
dataset['payment_type']
.replace({'not_defined': 'Unknown', 'boleto' : 'Bank Slip'})   # handle special case first
.str.replace('_', ' ')                 # replace underscores with spaces
.str.title()                           # then apply title case
)
    
# Dropping 3 rows with unknown paymentm impact is negligible to our 100K+ dataset

dataset = dataset[dataset['payment_type'] != 'Unknown']

# Column Name standardization

dataset.columns = dataset.columns.str.replace('_', ' ').str.title()
